# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# # About

# %%
models = "WT G43A G43C G43U C27A C27G C27U".split()
tids = [f"{i:02}" for i in range(0, 12)]

plt.rcParams.update({'font.size': 8})
plt.rcParams.update({'font.family': "Open Sans"})

# %% [markdown]
# ### H-bonds hinge quituple

# %%
# initialize figure
fig, ax = plt.subplots(figsize=(3.4, 2))

# initialize containers
means_all = []
xs = []
xs_means = []
means = []
rmsfs_models = []

x = 0
x_mean = 6
gap = 15

for model_i, model in enumerate(models):
    
    means = []
    
    for tid in tids:
        
        # read data
        xvg = f"../systems/{model}/hbonds.quintuple.{tid}.xvg"
        times, hbonds, pairs = np.loadtxt(xvg, comments="# @ &".split()).T
        
        # normalize length of the trajectories
        # analyze only the later parts
        times = times[7500:12500]
        hbonds = hbonds[7500:12500]
        
        means.append(np.mean(hbonds))
        
        xs.append(x)
        x += 1
           
    xs_means.append(x_mean)
    means_all.append(means)
    
    x += gap
    x_mean += (12 + gap)

# plot
ax.scatter(xs, np.array(means_all).flatten(), s=2, color="black")
ax.boxplot(means_all, positions=xs_means, widths=10, labels=models)

# layout
ax.set_title("five hinge nucleobases")
ax.set_ylabel("H-bonds")
# Out:
# Text(0, 0.5, 'H-bonds')

# %%
ps = []
for i in range(len(means_all)):
    p = stats.mannwhitneyu(means_all[0], means_all[i])
    ps.append(p.pvalue)
    print(models[i], p)
    
xs = np.arange(len(ps))
plt.scatter(xs, ps)
plt.xticks(xs, labels=models)
plt.yscale("log")
# Out:
# WT MannwhitneyuResult(statistic=72.0, pvalue=1.0)
# G43A MannwhitneyuResult(statistic=126.0, pvalue=0.0020095048556600134)
# G43C MannwhitneyuResult(statistic=119.0, pvalue=0.007259954988190575)
# G43U MannwhitneyuResult(statistic=110.0, pvalue=0.0303828219765775)
# C27A MannwhitneyuResult(statistic=78.0, pvalue=0.7508318840891169)
# C27G MannwhitneyuResult(statistic=59.0, pvalue=0.47048642205878966)
# C27U MannwhitneyuResult(statistic=87.0, pvalue=0.40250382378200356)

# %% [markdown]
# ### RMSD hinge quintuple

# %%
# initialize figure
fig, ax = plt.subplots(figsize=(3.4, 2))

# initialize containers
means_all = []
xs = []
xs_means = []
means = []
rmsfs_models = []

x = 0
x_mean = 6
gap = 15

for model_i, model in enumerate(models):
    
    means = []
    
    for tid in tids:
        
        xvg = f"../systems/{model}/rmsd.quintuple.fitNotStem.{tid}.xvg"
        times, rmsds = np.loadtxt(xvg, comments="# @ &".split()).T
        
        # normalize length of the trajectories
        # analyze only the later parts
        times = times[7500:12500]
        rmsds = rmsds[7500:12500]
        
        means.append(np.mean(rmsds))
        
        xs.append(x)
        x += 1
           
    xs_means.append(x_mean)
    means_all.append(means)
    
    x += gap
    x_mean += (12 + gap)

# plot
ax.scatter(xs, np.array(means_all).flatten(), s=2, color="black")
ax.boxplot(means_all, positions=xs_means, widths=10, labels=models)

# layout
ax.set_title("hinge quituple, fit not ttem")
ax.set_ylabel("RMSD / nm")
# Out:
# Text(0, 0.5, 'RMSD / nm')

# %%
ps = []
for i in range(len(means_all)):
    p = stats.mannwhitneyu(means_all[0], means_all[i])
    ps.append(p.pvalue)
    print(models[i], p)
    
xs = np.arange(len(ps))
plt.scatter(xs, ps)
plt.xticks(xs, labels=models)
plt.yscale("log")
# Out:
# WT MannwhitneyuResult(statistic=72.0, pvalue=1.0)
# G43A MannwhitneyuResult(statistic=33.0, pvalue=0.02622938783485702)
# G43C MannwhitneyuResult(statistic=32.0, pvalue=0.02257606252313358)
# G43U MannwhitneyuResult(statistic=53.0, pvalue=0.28547630885188247)
# C27A MannwhitneyuResult(statistic=76.0, pvalue=0.8398599725400034)
# C27G MannwhitneyuResult(statistic=73.0, pvalue=0.9769702553219757)
# C27U MannwhitneyuResult(statistic=76.0, pvalue=0.8398599725400034)

# %% [markdown]
# ### RMSD stem

# %%
# initialize figure
fig, ax = plt.subplots(figsize=(3.4, 2))

# initialize containers
means_all = []
xs = []
xs_means = []
means = []
rmsfs_models = []

x = 0
x_mean = 6
gap = 15

for model_i, model in enumerate(models):
    
    means = []
    
    for tid in tids:
        
        xvg = f"../systems/{model}/rmsd.stem.fitNotStem.{tid}.xvg"
        times, rmsds = np.loadtxt(xvg, comments="# @ &".split()).T
        
        # normalize length of the trajectories
        # analyze only the later parts
        times = times[7500:12500]
        rmsds = rmsds[7500:12500]
        
        means.append(np.mean(rmsds))
        
        xs.append(x)
        x += 1
           
    xs_means.append(x_mean)
    means_all.append(means)
    
    x += gap
    x_mean += (12 + gap)

# plot
ax.scatter(xs, np.array(means_all).flatten(), s=2, color="black")
ax.boxplot(means_all, positions=xs_means, widths=10, labels=models)

# layout
ax.set_title("stem, fit not stem")
ax.set_ylabel("RMSD / nm")
# Out:
# Text(0, 0.5, 'RMSD / nm')

# %%
ps = []
for i in range(len(means_all)):
    p = stats.mannwhitneyu(means_all[0], means_all[i])
    ps.append(p.pvalue)
    print(models[i], p)
    
x s=np.arange(len(ps))
plt.scatter(xs, ps)
plt.xticks(xs, labels=models)
plt.yscale("log")
# Out:
# WT MannwhitneyuResult(statistic=72.0, pvalue=1.0)
# G43A MannwhitneyuResult(statistic=42.0, pvalue=0.08853377201422956)
# G43C MannwhitneyuResult(statistic=25.0, pvalue=0.007259954988190575)
# G43U MannwhitneyuResult(statistic=85.0, pvalue=0.47048642205878966)
# C27A MannwhitneyuResult(statistic=121.0, pvalue=0.005107905424995494)
# C27G MannwhitneyuResult(statistic=54.0, pvalue=0.3123214216762161)
# C27U MannwhitneyuResult(statistic=82.0, pvalue=0.5833604667027033)
